# %% [markdown]
# # import csv

# %%
# load file
import pandas as pd

df = pd.read_csv('summary.csv')

print(len(df))
print(df)
# Out:
# 32
#     Unnamed: 0  animal  cond chan  new_sample_freq filter_type  lo_cutoff  \
# 0            0   58-21  base   g1              200    bandpass       0.05
# 1            0   58-21  base   g2              200    bandpass       0.05
# 2            0   58-21  base   g3              200    bandpass       0.05
# 3            0   58-21  base   g4              200    bandpass       0.05
# 4            0   58-21  feed   g1              200    bandpass       0.05
# 5            0   58-21  feed   g2              200    bandpass       0.05
# 6            0   58-21  feed   g3              200    bandpass       0.05
# 7            0   58-21  feed   g4              200    bandpass       0.05
# 8            0   60-21  base   g1              200    bandpass       0.05
# 9            0   60-21  base   g2              200    bandpass       0.05
# 10           0   60-21  base   g3              200    bandpass       0.05
# 11           0   60-21  base   g4              200    bandpass       0.05
# ...
